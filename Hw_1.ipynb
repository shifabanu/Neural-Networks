# %%
import pandas as pd
import matplotlib.pyplot as plt
import io
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0aa61bc2-9596-456e-8839-4c614631d748" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0aa61bc2-9596-456e-8839-4c614631d748">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris-data.csv to iris-data.csv

# %%
data = pd.read_csv(io.BytesIO(uploaded['iris-data.csv']))

# %%
data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  ...  petal_width_cm        class
# 0              5.1             3.5  ...             0.2  Iris-setosa
# 1              4.9             3.0  ...             0.2  Iris-setosa
# 2              4.7             3.2  ...             0.2  Iris-setosa
# 3              4.6             3.1  ...             0.2  Iris-setosa
# 4              5.0             3.6  ...             0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# The displayed data is the iris dataset that contains 5 columns as: sepal length, sepal width, petal length, petal width and class. All the columns except the class has numerical values. Class has some categorical values.

# %%
data.describe()
# Out:
#        sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm
# count       150.000000      150.000000       150.000000      145.000000
# mean          5.644627        3.054667         3.758667        1.236552
# std           1.312781        0.433123         1.764420        0.755058
# min           0.055000        2.000000         1.000000        0.100000
# 25%           5.100000        2.800000         1.600000        0.400000
# 50%           5.700000        3.000000         4.350000        1.300000
# 75%           6.400000        3.300000         5.100000        1.800000
# max           7.900000        4.400000         6.900000        2.500000

# %% [markdown]
# The summary of numerical features are shown above. It shows the maximum and minimum values. The sepal length has a bigger difference in the min and max values ie some data is wrong in that column. Other data looks good.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  150 non-null    float64
#  1   sepal_width_cm   150 non-null    float64
#  2   petal_length_cm  150 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# From the above code and details one can make out that there are a few missing values in the petal_width_cm column. Some data is missing. Also the class column has data type as object so it is a catergorical value.

# %%
# %matplotlib inline
data.hist(bins= 20, figsize= (20,15))
plt.show()

# %% [markdown]
# Observation of the above data:

# %% [markdown]
# Above figure shows histogram. The sepal length has some values equal to zero which means either it is a missing data or the data is wrongly entered. The histogram usually shows a better distribution of the whole data in each columns. It makes the analysis easy.

# %%
import seaborn as sns
plt.figure(figsize=(20,15))
corr = data.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# The above figure shows the correlation matrix plot. The matrix that are correlated has values near to -1 or 1. The ones that are not related to eachother have values near to 0.

# %%
from pandas.plotting import scatter_matrix
attributes = ["sepal_length_cm",	"sepal_width_cm",	"petal_length_cm",	"petal_width_cm"]
scatter_matrix(data[attributes], figsize= (20,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1dfe7d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1def1390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1de95a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1d9b5e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1df96048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1e1a7160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a10f813c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a137ad5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a137ad668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1dfd9b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a137f6d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1e055fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a1e01e278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a10ef54e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a10eac748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2a10e609b0>]],
#       dtype=object)

# %% [markdown]
# The above scatter plot shows the scatter matrix of each attribute mentioned in the code. The scatter plot with itself is a histogram whereas with others it is a scattered view.

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sepal_length_cm  145 non-null    float64
#  1   sepal_width_cm   145 non-null    float64
#  2   petal_length_cm  145 non-null    float64
#  3   petal_width_cm   145 non-null    float64
#  4   class            145 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.8+ KB

# %%
data.drop(data[data["sepal_width_cm"]<2.5].index, inplace= True)

# %%
data.head(50)
# Out:
#     sepal_length_cm  sepal_width_cm  ...  petal_width_cm            class
# 0               5.1             3.5  ...             0.2      Iris-setosa
# 1               4.9             3.0  ...             0.2      Iris-setosa
# 2               4.7             3.2  ...             0.2      Iris-setosa
# 3               4.6             3.1  ...             0.2      Iris-setosa
# 4               5.0             3.6  ...             0.2      Iris-setosa
# 5               5.4             3.9  ...             0.4      Iris-setosa
# 6               4.6             3.4  ...             0.3      Iris-setosa
# 12              4.8             3.0  ...             0.1      Iris-setosa
# 13              5.7             3.0  ...             0.1      Iris-setosa
# 14              5.8             4.0  ...             0.2      Iris-setosa
# 15              5.7             4.4  ...             0.4      Iris-setosa
# 16              5.4             3.9  ...             0.4      Iris-setosa
# 17              5.1             3.5  ...             0.3      Iris-setosa
# 18              5.7             3.8  ...             0.3     Iris-setossa
# 19              5.1             3.8  ...             0.3      Iris-setosa
# 20              5.4             3.4  ...             0.2      Iris-setosa
# 21              5.1             3.7  ...             0.4      Iris-setosa
# 22              4.6             3.6  ...             0.2      Iris-setosa
# 23              5.1             3.3  ...             0.5      Iris-setosa
# 24              4.8             3.4  ...             0.2      Iris-setosa
# 25              5.0             3.0  ...             0.2      Iris-setosa
# 26              5.0             3.4  ...             0.4      Iris-setosa
# 27              5.2             3.5  ...             0.2      Iris-setosa
# 28              5.2             3.4  ...             0.2      Iris-setosa
# 29              4.7             3.2  ...             0.2      Iris-setosa
# 30              4.8             3.1  ...             0.2      Iris-setosa
# 31              5.4             3.4  ...             0.4      Iris-setosa
# 32              5.2             4.1  ...             0.1      Iris-setosa
# 33              5.5             4.2  ...             0.2      Iris-setosa
# 34              4.9             3.1  ...             0.1      Iris-setosa
# 35              5.0             3.2  ...             0.2      Iris-setosa
# 36              5.5             3.5  ...             0.2      Iris-setosa
# 37              4.9             3.1  ...             0.1      Iris-setosa
# 38              4.4             3.0  ...             0.2      Iris-setosa
# 39              5.1             3.4  ...             0.2      Iris-setosa
# 40              5.0             3.5  ...             0.3      Iris-setosa
# 42              4.4             3.2  ...             0.2      Iris-setosa
# 43              5.0             3.5  ...             0.6      Iris-setosa
# 44              5.1             3.8  ...             0.4      Iris-setosa
# 45              4.8             3.0  ...             0.3      Iris-setosa
# 46              5.1             3.8  ...             0.2      Iris-setosa
# 47              4.6             3.2  ...             0.2      Iris-setosa
# 48              5.3             3.7  ...             0.2      Iris-setosa
# 49              5.0             3.3  ...             0.2      Iris-setosa
# 50              7.0             3.2  ...             1.4  Iris-versicolor
# 51              6.4             3.2  ...             1.5  Iris-versicolor
# 52              6.9             3.1  ...             1.5  Iris-versicolor
# 54              6.5             2.8  ...             1.5  Iris-versicolor
# 55              5.7             2.8  ...             1.3  Iris-versicolor
# 56              6.3             3.3  ...             1.6  Iris-versicolor
#
# [50 rows x 5 columns]

# %%
data["class"].value_counts()
# Out:
# Iris-virginica     49
# Iris-setosa        43
# Iris-versicolor    36
# versicolor          5
# Iris-setossa        1
# Name: class, dtype: int64

# %%
data.head()

# %%
data["class"].value_counts()

# %%
data["class"]= data["class"].replace("versicolor","Iris-versicolor")

# %%
data["class"].value_counts()

# %% [markdown]
# # New Section

# %%
data.loc[data['sepal_length_cm'] < 0.1, 'sepal_length_cm'] = data[ (data['sepal_length_cm']<0.1)]*100 
data["sepal_length_cm"]

# %%
data_cate = data[["class"]]
data_cate.info()

# %%
from sklearn.preprocessing import OneHotEncoder
cate_encode = OneHotEncoder()

iris_data_cate_encoder = cate_encode.fit_transform(data_cate)
iris_data_cate_encoder

# %%
iris_data_cate_encoder.toarray()

# %%
cate_encode.categories_

# %%
data.to_csv(r'tidy_iris_data.csv')

# %%
tidy = pd.read_csv("tidy_iris_data.csv")

# %%
tidy.head()

# %%
tidy["sepal_length_cm"][70:90]
